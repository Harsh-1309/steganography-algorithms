# %%
# Importing the OpenCV library 
import cv2 
# Reading the image using imread() function 
image = cv2.imread('a1.png') #use(,0) for directly loading images into gray scale


# will show the image in a window 
cv2.imshow('image', image) 
k = cv2.waitKey(0) & 0xFF
# wait for ESC key to exit 
if k == 27:  
    cv2.destroyAllWindows() 
#image = cv2.resize(image, (10,10))

# %%
# Extracting the height and width of an image 
h, w = image.shape[:2] 
# Displaying the height and width 
print("Height = {}, Width = {}".format(h, w))
# Out:
# Height = 768, Width = 1504

# %%
# Extracting RGB values.  
# Here we have randomly chosen a pixel 
# by passing in 100, 100 for height and width, can be custom in image[,]
(B, G, R) = image[700, 800] 
  
# Displaying the pixel values 
print("R = {}, G = {}, B = {}".format(R, G, B)) 
  
# We can also pass the channel to extract  
# the value for a specific channel 
BC = image[100, 100, 0] 
print("BC = {}".format(BC))
# Out:
# R = 74, G = 70, B = 25
# BC = 148

# %%
# We use cvtColor, to convert to grayscale 
#gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
  
#cv2.imshow('Grayscale', gray_image) 
#cv2.waitKey(0)   
  
# window shown waits for any key pressing event 
#cv2.destroyAllWindows()

# %%
#(g) = image[700, 800] 
  
# Displaying the pixel values 
#print("g = {}".format(g))

# %%
A=[] #creating lists for range input for private stego key
B=[]
def InputFn(): #function for input
    A.clear()
    B.clear()
    i=0
    while(i<5):
        a=int(input("enter lower limit" )) 
        A.append(a)
        print()
        b=int(input("enter upper limit" ))
        B.append(b)
        print()
        i+=1

# %%
InputFn() #taking input
# Out:
# enter lower limit2
#
# enter upper limit36
#
# enter lower limit38
#
# enter upper limit73
#
# enter lower limit74
#
# enter upper limit102
#
# enter lower limit105
#
# enter upper limit170
#
# enter lower limit178
#
# enter upper limit245

# %%
#data validation
def dataval():
    for i in range(0,5):
        if A[i+1]<=A[i] or B[i+1]<=B[i] or A[i]<0 or A[i]>255 or B[i]<0 or B[i]>255 or (B[i]-A[i])<32 :
            print("invalid input, enter again:")
            InputFn()
            dataval() 
            break
        else:
            print("the range choosen is :") 
            for i in range(0,5):
                print("(",A[i],",",B[i],")")
            break

# %%
dataval()
# Out:
# the range choosen is :
# ( 2 , 36 )
# ( 38 , 73 )
# ( 74 , 102 )
# ( 105 , 170 )
# ( 178 , 245 )

# %%
BC = image[100, 100, 0] 
print("BC = {}".format(BC))
# Out:
# BC = 148

# %%
# Extracting the height and width of an image 
h, w = image.shape[:2] 
# Displaying the height and width 
print("Height = {}, Width = {}".format(h, w))
# Out:
# Height = 768, Width = 1504

# %%
s1=0;s2=0;s3=0;s4=0;s5=0
for i in range(0,h):
    for j in range(0,w):
        BC=image[i,j,0]
        if A[0]<=BC<=B[0]:
            s1=s1+1
        if A[1]<=BC<=B[1]:
            s2=s2+1
        if A[2]<=BC<=B[2]:
            s3=s3+1
        if A[3]<=BC<=B[3]:
            s4=s4+1
        if A[4]<=BC<=B[4]:
            s5=s5+1

# %%
N=[]
N.append(s1)
N.append(s2)
N.append(s3)
N.append(s4)
N.append(s5)

# %%
for i in range(0,5):
    print("No of pixels in range",i+1,'is',N[i])
# Out:
# No of pixels in range 1 is 671783
# No of pixels in range 2 is 158743
# No of pixels in range 3 is 59041
# No of pixels in range 4 is 253462
# No of pixels in range 5 is 6

# %%
I=[]
for i in range(0,5):
    m=int(input("enter next maximum no of message bits insertion "))
    I.append(m)
# Out:
# enter next maximum no of message bits insertion 5
# enter next maximum no of message bits insertion 4
# enter next maximum no of message bits insertion 3
# enter next maximum no of message bits insertion 2
# enter next maximum no of message bits insertion 1

# %%
M=N.copy()
li=[] 
  
for i in range(5): 
      li.append([M[i],i]) 
li.sort(reverse=True) 
sort_index = [] 
  
for x in li: 
      sort_index.append(x[1]) 
  
 #print(sort_index)
for i in range(0,5):
    print(I[i],"bits to be inserted in range", sort_index[i]+1)
# Out:
# 5 bits to be inserted in range 1
# 4 bits to be inserted in range 4
# 3 bits to be inserted in range 2
# 2 bits to be inserted in range 3
# 1 bits to be inserted in range 5

# %%
# Converting String to binary 
# Using join() + ord() + format() 
  
# initializing string  
message = input("enter message to hide : ")
  
# printing original string  
print("The original message is : " + str(message)) 
  
# using join() + ord() + format() 
# Converting String to binary 
b_message = ''.join(format(ord(i), 'b') for i in message) 
  
# printing result  
print("The message after binary conversion : " + str(b_message))
# Out:
# enter message to hide : harsh
# The original message is : harsh
# The message after binary conversion : 11010001100001111001011100111101000

# %%
b_message
# Out:
# '11010001100001111001011100111101000'

# %%
Message=b_message

# %%
l=int(len(b_message))

# %%
#BC=image[23,45,0]

# %%
#BC

# %%
#BC=image.itemset((23,45,0),160)

# %%
#BC

# %%
#print(BC)

# %%
#image.item(23,45,0)

# %%
#n=160

# %%
#b=bin(n).replace("0b", "")

# %%
#len(b)

# %%
def rangefinder():    #to substitute bits
    if A[0]<=BC<=B[0]:
        return 'range1'
       
    if A[1]<=BC<=B[1]:
        return 'range2'
        
    if A[2]<=BC<=B[2]:          
        return 'range3'
        
    if A[3]<=BC<=B[3]:  
        return 'range4'
        
    if A[4]<=BC<=B[4]: 
        return 'range5'

# %%
#for i in range (0,5):
 #   h=exec("%s=%d" % ('r'+str(sort_index[i]+1),2))
  #  print(h)

# %%
r1=5;r2=4;r3=3;r4=2;r5=1

# %%
def bitchanger():
    for i in range(len(b_message)):
        if rangefinder()=='range1':
            BC_bin=bin(BC).replace("0b","")
            BC_bin_mod=BC_bin[0:3]+b_message[i:i+6]  
            # Convert n to base 2
            s = int(BC_bin_mod, 10)
            image.itemset((n,j,0),s)
            i=i+5
            
        if rangefinder()=='range2':
            BC_bin=bin(BC).replace("0b","")
            BC_bin_mod=BC_bin[0:4]+b_message[i:i+5]  
            # Convert n to base 2
            s = int(BC_bin_mod, 10)
            image.itemset((n,j,0),s)
            i=i+4
            
        if rangefinder()=='range3':
            BC_bin=bin(BC).replace("0b","")
            BC_bin_mod=BC_bin[0:5]+b_message[i:i+4]  
            # Convert n to base 2
            s = int(BC_bin_mod, 10)
            image.itemset((n,j,0),s)
            i=i+3
            
        if rangefinder()=='range4':
            BC_bin=bin(BC).replace("0b","")
            BC_bin_mod=BC_bin[0:6]+b_message[i:i+3]  
            # Convert n to base 2
            s = int(BC_bin_mod, 10)
            image.itemset((n,j,0),s)
            i=i+2
        
        if rangefinder()=='range5':
            BC_bin=bin(BC).replace("0b","")
            BC_bin_mod=BC_bin[0:7]+b_message[i:i+2]  
            # Convert n to base 2
            s = int(BC_bin_mod, 10)
            image.itemset((n,j,0),s)
            i=i+1
        if i>=len(b_message):
            print("end of string")
        break

# %%
if l>(h*w):
    print("use a larger image")
    
else :
    for n in range(0,h):
        for j in range(0,w):
            BC=image[n,j,0]
            rangefinder()
            bitchanger()
            #if n*j>len(b_message):
                
                #break
        print(rangefinder())    
        #if n*j<len(b_message):
            #print("end of message")
            #break
# Out:
# None
# None
# range4
# range4
# range4
# range1
# range1
# range1
# range1
# range1
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# None
# None
# None
# None
# None
# None
# None
# None
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# None
# None
# None
# None
# None
# None
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range5
# range5
# range5
# range5
# range4
# range4
# range4
# range4
# range5
# range5
# range2
# None
# range2
# range4
# range1
# range1
# range4
# range5
# range5
# range5
# range4
# range5
# range5
# range5
# range2
# range5
# range2
# range2
# range2
# range5
# range5
# range5
# range1
# range2
# range5
# range2
# range5
# range2
# range1
# range1
# range1
# range1
# range5
# range4
# range4
# range4
# range3
# range4
# range1
# range4
# range3
# range1
# range1
# range3
# range4
# range3
# range1
# range1
# range3
# range3
# range5
# range5
# range5
# range1
# range1
# range1
# range4
# range3
# range1
# range1
# range1
# range3
# range1
# range5
# range1
# range1
# range3
# range1
# range4
# range5
# range3
# range5
# range5
# range3
# range5
# range3
# range1
# range5
# range4
# range5
# range2
# range5
# range4
# range3
# range1
# range4
# range1
# range1
# range3
# range3
# range3
# range4
# range3
# range3
# range4
# range4
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range4
# range5
# range5
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range4
# range5
# range5
# range4
# range3
# range4
# range5
# range2
# range4
# range1
# range1
# range1
# range4
# range3
# range3
# range3
# range1
# range1
# range1
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range3
# range4
# range3
# range4
# range4
# range4
# range5
# range5
# range5
# range5
# range5
# range5
# range5
# range5
# range5
# range5
# range1
# range4
# range2
# range5
# range4
# range5
# range5
# range2
# range5
# range2
# range4
# range1
# range1
# None
# None
# range1
# range4
# None
# range1
# range1
# range1
# range1
# range1
# range5
# range5
# range1
# range1
# range4
# range2
# range5
# range5
# range4
# range1
# range1
# range4
# range5
# range2
# range4
# range1
# range1
# range1
# range1
# range1
# range1
# range1
# range4
# range5
# range5
# range5
# range5
# range5
# range2
# range4
# range1
# range4
# range5
# range1
# range5
# range5
# range5
# range4
# range5
# range5
# range1
# range1
# range5
# range5
# range1
# range1
# range5
# range1
# range5
# range2
# range5
# range4
# range4
# range5
# range5
# range4
# range4
# range4
# range4
# range4
# range3
# range3
# range3
# range3
# range3
# range4
# range5
# range5
# range5
# range5
# range4
# range3
# range4
# range4
# range5
# range4
# range4
# range5
# range1
# range1
# range1
# range1
# range4
# range5
# range5
# range4
# range5
# range4
# range5
# range1
# range5
# range4
# range4
# range3
# range1
# range3
# range3
# range3
# range3
# range3
# range5
# range3
# range3
# range1
# range1
# range4
# range5
# range4
# range4
# range1
# range5
# range1
# range5
# range1
# range4
# range4
# range5
# range1
# range1
# None
# range1
# range4
# range4
# range4
# range5
# range5
# range5
# range5
# range1
# range1
# range5
# range5
# range5
# range5
# range5
# range1
# range4
# range1
# range3
# range4
# range4
# range1
# range1
# range3
# range4
# range1
# range1
# range4
# range4
# range1
# range4
# range4
# range3
# range1
# range4
# range1
# range5
# range3
# range5
# range4
# range1
# range4
# range3
# range4
# range4
# range3
# range5
# range1
# range4
# range5
# range4
# range5
# range1
# range1
# range5
# range1
# range1
# range1
# range5
# range5
# range1
# range5
# range1
# range1
# range5
# range3
# range1
# range5
# range1
# range3
# range3
# range3
# range4
# range5
# range4
# range3
# range1
# range1
# range1
# range3
# range3
# range1
# range1
# range5
# range3
# range3
# range5
# range5
# range3
# range3
# range3
# range1
# range1
# range1
# range1
# range3
# range5
# range5
# range5
# range5
# range5
# range5
# range3
# range1
# range1
# range5
# range4
# range4
# range4
# range3
# range5
# range1
# range1
# range1
# range1
# range4
# range1
# range3
# range1
# range3
# range1
# range3
# range1
# range1
# range5
# range5
# range1
# range3
# range5
# range5
# range1
# range5
# range1
# range3
# range3
# range4
# range3
# range1
# range1
# range3
# range5
# range4
# range3
# range1
# range1
# range1
# range1
# range3
# range1
# range1
# range5
# range5
# range3
# range5
# range4
# range1
# range1
# range1
# range1
# range1
# range5
# range5
# range4
# range1
# range5
# range4
# range1
# range1
# range1
# range1
# range3
# range1
# range4
# range5
# range5
# range1
# range1
# range5
# range4
# range5
# range4
# range1
# range5
# range1
# range1
# range3
# range4
# range5
# range3
# range1
# range4
# range5
# range4
# range4
# range5
# range1
# range3
# range1
# range3
# range4
# range5
# range4
# range4
# range5
# range1
# range3
# range4
# range1
# range1
# range5
# range4
# range1
# range4
# range1
# range5
# range3
# range4
# range3
# range4
# range5
# range1
# range1
# range3
# range1
# range1
# range4
# range5
# range3
# range1
# range2
# range1
# range4
# range4
# range5
# range1
# range5
# range5
# range5
# range1
# range3
# range5

# %%
B
# Out:
# [36, 73, 102, 170, 245]

# %%
stego_image=image

# %%
# will show the image in a window 
cv2.imshow('stego_image', image) 
k = cv2.waitKey(0) & 0xFF
# wait for ESC key to exit 
if k == 27:  
    cv2.destroyAllWindows()

# %%
#message=[]

# %%
def rangefinder_D():    
    if A[0]<=BC<=B[0]:
        return 'range1'
       
    if A[1]<=BC<=B[1]:
        return 'range2'
        
    if A[2]<=BC<=B[2]:          
        return 'range3'
        
    if A[3]<=BC<=B[3]:  
        return 'range4'
        
    if A[4]<=BC<=B[4]: 
        return 'range5'

# %%
def bitchanger_D():
    message=[]
    message.clear()
    for i in range(len(b_message)):
        if rangefinder_D()=='range1':
            BC_bin_D=bin(BC).replace("0b","")
            BC_bin_M=BC_bin_D[4:9]  
            # Convert n to base 2
            #s = int(BC_bin_M, 10)
            message.append(BC_bin_M)
            i=i+5
            
        if rangefinder_D()=='range2':
            BC_bin_D=bin(BC).replace("0b","")
            BC_bin_M=BC_bin_D[5:9]  
            # Convert n to base 2
           # s = int(BC_bin_M, 10)
            message.append(BC_bin_M)
            i=i+5
            
        if rangefinder_D()=='range3':
            BC_bin_D=bin(BC).replace("0b","")
            BC_bin_M=BC_bin_D[6:9]  
            # Convert n to base 2
           # s = int(BC_bin_M, 10)
            message.append(BC_bin_M)
            i=i+5
            
        if rangefinder_D()=='range4':
            BC_bin_D=bin(BC).replace("0b","")
            BC_bin_M=BC_bin_D[7:9]  
            # Convert n to base 2
            #s = int(BC_bin_M, 10)
            message.append(BC_bin_M)
            i=i+5    
            
        if rangefinder_D()=='range5':
            BC_bin_D=bin(BC).replace("0b","")
            BC_bin_M=BC_bin_D[8:9]  
            # Convert n to base 2
           # s = int(BC_bin_M, 10)
            message.append(BC_bin_M)
            i=i+5  
            
        #if i>=len(b_message):
           # break
    #print("end of string")

# %%
image.item(2,2,0)
# Out:
# 6

# %%
for n in range(0,h):
    for j in range(0,w):
        BC=stego_image[n,j,0]
        rangefinder_D()
        bitchanger_D()
    #print(rangefinder_D())    
    if n*j<len(b_message):
        print("end of message")
    break
# Out:
# end of message

# %%
print(Message)
# Out:
# 11010001100001111001011100111101000

# %%
def BinaryToDecimal(binary): 
      
    # Using int function to convert to 
    # string    
    string = int(binary, 2) 
      
    return string 
      
# Driver's code 
# initializing binary data 
bin_data =Message
   
# print binary data 
print("The binary value is:", bin_data) 
   
# initializing a empty string for  
# storing the string data 
str_data =' '
   
# slicing the input and converting it  
# in decimal and then converting it in string 
for i in range(0, len(bin_data), 7): 
      
    # slicing the bin_data from index range [0, 6] 
    # and storing it in temp_data 
    temp_data = bin_data[i:i + 7] 
       
    # passing temp_data in BinarytoDecimal() function 
    # to get decimal value of corresponding temp_data 
    decimal_data = BinaryToDecimal(temp_data) 
       
    # Deccoding the decimal value returned by  
    # BinarytoDecimal() function, using chr()  
    # function which return the string corresponding  
    # character for given ASCII value, and store it  
    # in str_data 
    str_data = str_data + chr(decimal_data)  
   
print("The value after string conversion is:", 
       str_data)
# Out:
# The binary value is: 11010001100001111001011100111101000
# The Binary value after string conversion is:  harsh

# %%
if Message == b_message:
    print("data extraction successful")
# Out:
# data extraction successful

# %%
print("the message sent was:", str_data)
# Out:
# the message sent was:  harsh
